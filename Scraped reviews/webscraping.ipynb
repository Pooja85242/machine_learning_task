# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %% [markdown]
# # One-plus 7T

# %%
link='https://www.amazon.in/Test-Exclusive-748/product-reviews/B07DJLVJ5M/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

# %%
page = requests.get(link)

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|012LjolmrML.css,41-crZfIjzL.css,11cMnOipjJL.css,017DsKjNQJL.css,01Vctty9pOL.css,01HEsUOLYvL.css,41EWOOlBJ9L.css,11PIM2x8KnL.css,01ElnPiDxWL.css,11QxHU4QYaL.css,01Sp8sB1HiL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,01evdoiemkL.css,01K+Ps1DeEL.css,314djKvMsUL.css,01ZTetsDh7L.css,01pbA9Lg3yL.css,21LK7jaicML.css,11L58Qpo0GL.css,21kyTi1FabL.css,01ruG+gDPFL.css,01YhS3Cs-hL.css,21GwE3cR
# ...

# %%
soup =bs(page.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:feature:aui-assets -->
# ...

# %%
names = soup.find_all('span',class_='a-profile-name')

# %%
names
# Out:
# [<span class="a-profile-name">Amazon Customer</span>,
#  <span class="a-profile-name">Praggya</span>,
#  <span class="a-profile-name">Praggya</span>,
#  <span class="a-profile-name">Amazon Customer</span>,
#  <span class="a-profile-name">Kshitij Kumar</span>,
#  <span class="a-profile-name">manikanta</span>,
#  <span class="a-profile-name">Vicky Sen</span>,
#  <span class="a-profile-name">Rajesh Adhikary</span>,
#  <span class="a-profile-name">KESH</span>,
#  <span class="a-profile-name">Dheeraj Malhotra</span>,
#  <span class="a-profile-name">Avengers</span>,
#  <span class="a-profile-name">Nitish Kumar</span>]

# %%
cust_name = []
for i in range(0,len(names)):
    cust_name.append(names[i].get_text())

# %%
cust_name
# Out:
# ['Amazon Customer',
#  'Praggya',
#  'Praggya',
#  'Amazon Customer',
#  'Kshitij Kumar',
#  'manikanta',
#  'Vicky Sen',
#  'Rajesh Adhikary',
#  'KESH',
#  'Dheeraj Malhotra',
#  'Avengers',
#  'Nitish Kumar']

# %%
cust_name.pop(1)
# Out:
# 'Praggya'

# %%
cust_name
# Out:
# ['Amazon Customer',
#  'Praggya',
#  'Amazon Customer',
#  'Kshitij Kumar',
#  'manikanta',
#  'Vicky Sen',
#  'Rajesh Adhikary',
#  'KESH',
#  'Dheeraj Malhotra',
#  'Avengers',
#  'Nitish Kumar']

# %%
cust_name.pop(0)
# Out:
# 'Amazon Customer'

# %%
cust_name
# Out:
# ['Praggya',
#  'Amazon Customer',
#  'Kshitij Kumar',
#  'manikanta',
#  'Vicky Sen',
#  'Rajesh Adhikary',
#  'KESH',
#  'Dheeraj Malhotra',
#  'Avengers',
#  'Nitish Kumar']

# %%
title = soup.find_all('a',class_='review-title-content')

# %%
title
# Out:
# [<a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R3LLWXXD1Z1H2V?ASIN=B07DJLVJ5M">
#  <span>Think and evaluate before you go for it</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R34CR90W5F1MR7?ASIN=B07DJLVJ5M">
#  <span>Treat to the eye</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/RHCUTQ5LT7BTQ?ASIN=B07DJLVJ5M">
#  <span>Best experience</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/RJ1XR61YJSJ7S?ASIN=B07DJLVJ5M">
#  <span>One Plus 7T - One Word, STUNNING!!</span>
#  </a>,
# ...

# %%
review_title = []
for i in range(0,len(title)):
    review_title.append(title[i].get_text())

review_title
# Out:
# ['\nThink and evaluate before you go for it\n',
#  '\nTreat to the eye\n',
#  '\nBest experience\n',
#  '\nOne Plus 7T - One Word, STUNNING!!\n',
#  '\nPlease improve your build quality other wise india will fire you 😠\n',
#  '\nPro Camera, performance, looks. Cons Battery drain and heating up issues\n',
#  "\nPLEASE SAVE YOUR MONEY AND DON'T BUY THIS PHONE.\n",
#  '\nNo earphone jack\n',
#  '\nGood phone\n',
#  '\nNot recommended at all\n']

# %%
review_title[:] = [titles.lstrip('\n') for titles in review_title]

# %%
review_title[:] = [titles.rstrip('\n') for titles in review_title]

# %%
review_title
# Out:
# ['Think and evaluate before you go for it',
#  'Treat to the eye',
#  'Best experience',
#  'One Plus 7T - One Word, STUNNING!!',
#  'Please improve your build quality other wise india will fire you 😠',
#  'Pro Camera, performance, looks. Cons Battery drain and heating up issues',
#  "PLEASE SAVE YOUR MONEY AND DON'T BUY THIS PHONE.",
#  'No earphone jack',
#  'Good phone',
#  'Not recommended at all']

# %%
rating =  soup.find_all('i',class_='review-rating')
rating
# Out:
# [<i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating-view-point"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-3 review-rating" data-hook="review-star-rating-view-point"><span class="a-icon-alt">3.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-3 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">3.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>,
# ...

# %%
rate = []
for i in range(0,len(rating)):
    rate.append(rating[i].get_text())

# %%
rate
# Out:
# ['4.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars']

# %%
len(rate)
# Out:
# 12

# %%
rate.pop(0)
# Out:
# '4.0 out of 5 stars'

# %%
rate
# Out:
# ['3.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars']

# %%
rate.pop(0)
# Out:
# '3.0 out of 5 stars'

# %%
rate
# Out:
# ['3.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars']

# %%
review = soup.find_all('span',class_='review-text-content')

# %%
review
# Out:
# [<span class="a-size-base review-text review-text-content" data-hook="review-body">
#  <span>
# ...

# %%
review_content = []
for i in range(0,len(review)):
    review_content.append(review[i].get_text())

# %%
review_content
# Out:
# ["\n\n  After reading a lot of geeky reviews on YouTube and portals, I bought Oneplus7t. Pls, note I have been using OnePlus from last many years now so my expectations were clear. My experience with the device says that most of the reviews or unboxing things are influenced. Pls, note I have bought it with my own money unlike leading reviewers or unboxing video geeks who get it for free. So pls don't go by them blindly. Go for users reviews who bought them with their own money. So I am writing my 5 days experience with the phone.I am not a gamer or a geek. A regular user who wants to do all the office work on the phone, social media, blogging and vlogging, etc.The last OnePlus phone I was using was Oneplus 5 and was quite happy with it until it screen got broken and replacement cost was higher than the selling price of the device itself.The day it arrived from Amazon I opened it with a lot of excitement which continued till I have held it in my hands.Here are the issues:1. Weight: It
# ...

# %%
review_content[:] = [content.lstrip('\n') for content in review_content]

# %%
review_content[:] = [content.rstrip('\n') for content in review_content]

# %%
review_content
# Out:
# ["  After reading a lot of geeky reviews on YouTube and portals, I bought Oneplus7t. Pls, note I have been using OnePlus from last many years now so my expectations were clear. My experience with the device says that most of the reviews or unboxing things are influenced. Pls, note I have bought it with my own money unlike leading reviewers or unboxing video geeks who get it for free. So pls don't go by them blindly. Go for users reviews who bought them with their own money. So I am writing my 5 days experience with the phone.I am not a gamer or a geek. A regular user who wants to do all the office work on the phone, social media, blogging and vlogging, etc.The last OnePlus phone I was using was Oneplus 5 and was quite happy with it until it screen got broken and replacement cost was higher than the selling price of the device itself.The day it arrived from Amazon I opened it with a lot of excitement which continued till I have held it in my hands.Here are the issues:1. Weight: It wei
# ...

# %%
len(review_content)
# Out:
# 10

# %%
df = pd.DataFrame()

# %%
df['Customer Name'] = cust_name

# %%
df['Review Title'] = review_title

# %%
df['Rate'] =rate

# %%
df['Review Content'] = review_content

# %%
df
# Out:
#       Customer Name                                       Review Title  \
# 0           Praggya            Think and evaluate before you go for it
# 1   Amazon Customer                                   Treat to the eye
# 2     Kshitij Kumar                                    Best experience
# 3         manikanta                 One Plus 7T - One Word, STUNNING!!
# 4         Vicky Sen  Please improve your build quality other wise i...
# 5   Rajesh Adhikary  Pro Camera, performance, looks. Cons Battery d...
# 6              KESH   PLEASE SAVE YOUR MONEY AND DON'T BUY THIS PHONE.
# 7  Dheeraj Malhotra                                   No earphone jack
# 8          Avengers                                         Good phone
# 9      Nitish Kumar                             Not recommended at all
#
#                  Rate                                     Review Content
# 0  3.0 out of 5 stars    After reading a lot of geeky reviews on YouT...
# ...

# %%
df.to_csv(r'C:\Users\pooja\Downloads\customer_review.csv',index = True)

# %% [markdown]
# # Samsung Galaxy M31

# %%
link2 ='https://www.amazon.in/Samsung-Galaxy-Ocean-128GB-Storage/product-reviews/B07HGGYWL6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

# %%
page = requests.get(link2)

# %%
page
# Out:
# <Response [200]>

# %%
soup = bs(page.content,'html.parser')

# %%
name = soup.find_all('span',class_='a-profile-name')

# %%
name
# Out:
# [<span class="a-profile-name">shailesh</span>,
#  <span class="a-profile-name">surojit das</span>,
#  <span class="a-profile-name">shailesh</span>,
#  <span class="a-profile-name">Ajay KS</span>,
#  <span class="a-profile-name">surojit das</span>,
#  <span class="a-profile-name">Riddham Jain</span>,
#  <span class="a-profile-name">Anshul</span>,
#  <span class="a-profile-name">Abhinav</span>,
#  <span class="a-profile-name">abin abraham</span>,
#  <span class="a-profile-name">Akshaykumar Patil</span>,
#  <span class="a-profile-name">Veerababu Puli</span>,
#  <span class="a-profile-name">TUSHAR GOMASE</span>]

# %%
cust_name = []
for i in range(0,len(name)):
    cust_name.append(name[i].get_text())
    
cust_name
# Out:
# ['shailesh',
#  'surojit das',
#  'shailesh',
#  'Ajay KS',
#  'surojit das',
#  'Riddham Jain',
#  'Anshul',
#  'Abhinav',
#  'abin abraham',
#  'Akshaykumar Patil',
#  'Veerababu Puli',
#  'TUSHAR GOMASE']

# %%
cust_name.pop(0)
# Out:
# 'shailesh'

# %%
cust_name
# Out:
# ['surojit das',
#  'shailesh',
#  'Ajay KS',
#  'surojit das',
#  'Riddham Jain',
#  'Anshul',
#  'Abhinav',
#  'abin abraham',
#  'Akshaykumar Patil',
#  'Veerababu Puli',
#  'TUSHAR GOMASE']

# %%
cust_name.pop(0)
# Out:
# 'surojit das'

# %%
cust_name
# Out:
# ['shailesh',
#  'Ajay KS',
#  'surojit das',
#  'Riddham Jain',
#  'Anshul',
#  'Abhinav',
#  'abin abraham',
#  'Akshaykumar Patil',
#  'Veerababu Puli',
#  'TUSHAR GOMASE']

# %%
title = soup.find_all('a',class_='review-title-content')
title
# Out:
# [<a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/RRZ9IB7F5IZ9Y?ASIN=B07HGGYWL6">
#  <span>Samsung m31 all rounder  best mobile.</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R1TWCJK86LRH45?ASIN=B07HGGYWL6">
#  <span>Best Value for Money in this Range. Go for it without any doubt.</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/RE82U6E9ZJ9JQ?ASIN=B07HGGYWL6">
#  <span>Poor camera</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R30YCZQI647KNF?ASIN=B07HGGYWL6">
# ...

# %%
review_title = []
for i in range(0,len(title)):
    review_title.append(title[i].get_text())
    
review_title
# Out:
# ['\nSamsung m31 all rounder  best mobile.\n',
#  '\nBest Value for Money in this Range. Go for it without any doubt.\n',
#  '\nPoor camera\n',
#  '\nFalse ads, poor camera quality, inefficient battery management\n',
#  '\nInferior quality and built\n',
#  '\nSerious Issue\n',
#  '\nNot good at alll\n',
#  "\nSamsung it's not fair .\n",
#  '\nWorst phone\n',
#  '\nBad Product by Samsung\n']

# %%
review_title[:] = [titles.lstrip('\n') for titles in review_title]

# %%
review_title[:] = [titles.rstrip('\n') for titles in review_title]

# %%
review_title
# Out:
# ['Samsung m31 all rounder  best mobile.',
#  'Best Value for Money in this Range. Go for it without any doubt.',
#  'Poor camera',
#  'False ads, poor camera quality, inefficient battery management',
#  'Inferior quality and built',
#  'Serious Issue',
#  'Not good at alll',
#  "Samsung it's not fair .",
#  'Worst phone',
#  'Bad Product by Samsung']

# %%
rating = soup.find_all('i',class_='review-rating')

# %%
rate = []
for i in range(0,len(rating)):
    rate.append(rating[i].get_text())

rate
# Out:
# ['5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '3.0 out of 5 stars']

# %%
len(rate)
# Out:
# 12

# %%
rate.pop(0)
# Out:
# '5.0 out of 5 stars'

# %%
rate
# Out:
# ['1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '3.0 out of 5 stars']

# %%
rate.pop(0)
# Out:
# '1.0 out of 5 stars'

# %%
rate
# Out:
# ['5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '3.0 out of 5 stars']

# %%
review = soup.find_all('span',class_='review-text-content')

# %%
review_content =[]
for i in range(0,len(review)):
    review_content.append(review[i].get_text())

review_content
# Out:
# ['\n\n  Best camera, very good battery life, eat body material, average weight, best performance,  best display.\n\n',
# ...

# %%
review_content[:] = [content.lstrip('\n') for content in review_content]

# %%
review_content[:] = [content.rstrip('\n') for content in review_content]

# %%
review_content
# Out:
# ['  Best camera, very good battery life, eat body material, average weight, best performance,  best display.',
# ...

# %%
import pandas as pd
df2 = pd.DataFrame()

# %%
df2['Customer Name'] = cust_name

# %%
df2['Review title'] = review_title

# %%
df2['Rating'] = rate

# %%
df2['Review Content'] = review_content

# %%
df2
# Out:
#        Customer Name                                       Review title  \
# 0           shailesh              Samsung m31 all rounder  best mobile.
# 1            Ajay KS  Best Value for Money in this Range. Go for it ...
# 2        surojit das                                        Poor camera
# 3       Riddham Jain  False ads, poor camera quality, inefficient ba...
# 4             Anshul                         Inferior quality and built
# 5            Abhinav                                      Serious Issue
# 6       abin abraham                                   Not good at alll
# 7  Akshaykumar Patil                            Samsung it's not fair .
# 8     Veerababu Puli                                        Worst phone
# 9      TUSHAR GOMASE                             Bad Product by Samsung
#
#                Rating                                     Review Content
# 0  5.0 out of 5 stars    Best camera, very good battery life, eat bod...
# ...

# %%
df2.to_csv(r'C:\Users\pooja\Downloads\customer_review_samsung.csv',index = True)

# %% [markdown]
# # Apple iphone 11

# %%
link3 = 'https://www.amazon.in/Apple-iPhone-11-64GB-Black/product-reviews/B07XVMDRZY/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

# %%
page = requests.get(link3)

# %%
page
# Out:
# <Response [200]>

# %%
soup = bs(page.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:feature:aui-assets -->
# ...

# %%
names = soup.find_all('span',class_='a-profile-name')
cust_name = []
for i in range(0,len(names)):
    cust_name.append(names[i].get_text())

cust_name
# Out:
# ['shanu Kumar',
#  'Suman Biswas',
#  'Suman Biswas',
#  'Neha',
#  'shanu Kumar',
#  'Sunny Kumar',
#  'Amazon Customer',
#  'Krusshna',
#  'Satyapal singh',
#  'Gurmeet singh',
#  'Ghar Sayan',
#  'Vinay Kumar Gupta']

# %%
cust_name.pop(0)
# Out:
# 'shanu Kumar'

# %%
cust_name.pop(0)
# Out:
# 'Suman Biswas'

# %%
cust_name
# Out:
# ['Suman Biswas',
#  'Neha',
#  'shanu Kumar',
#  'Sunny Kumar',
#  'Amazon Customer',
#  'Krusshna',
#  'Satyapal singh',
#  'Gurmeet singh',
#  'Ghar Sayan',
#  'Vinay Kumar Gupta']

# %%
title = soup.find_all('a',class_='review-title')
review_title = []
for i in range(0,len(title)):
    review_title.append(title[i].get_text())
    

review_title
# Out:
# ["\nKeep away from Amazon when it's Apple.\n",
#  '\nDo not buy iphone or expensive product from Amazom\n',
#  '\nSolid premium phone from Apple\n',
#  '\nFirst Time iPhone User Review :-)\n',
#  '\nWorst Experience Ever.!\n',
#  '\nDon’t buy it from this seller\n',
#  '\niPhone 11\n',
#  '\nDefective Iphone 11\n',
#  '\nBest iPhone ever | Super Night Mode | Super Camera | Yellow\n',
#  '\nToo much heat on normal use\n']

# %%
review_title[:] = [titles.lstrip('\n') for titles in review_title]

# %%
review_title[:] = [titles.rstrip('\n') for titles in review_title]

# %%
review_title
# Out:
# ["Keep away from Amazon when it's Apple.",
#  'Do not buy iphone or expensive product from Amazom',
#  'Solid premium phone from Apple',
#  'First Time iPhone User Review :-)',
#  'Worst Experience Ever.!',
#  'Don’t buy it from this seller',
#  'iPhone 11',
#  'Defective Iphone 11',
#  'Best iPhone ever | Super Night Mode | Super Camera | Yellow',
#  'Too much heat on normal use']

# %%
ratings = soup.find_all('i',class_='review-rating')
rate = []
for i in range(0,len(ratings)):
    rate.append(ratings[i].get_text())
    

rate
# Out:
# ['5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars']

# %%
rate.pop(0)
# Out:
# '5.0 out of 5 stars'

# %%
rate.pop(0)
# Out:
# '1.0 out of 5 stars'

# %%
rate
# Out:
# ['1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars']

# %%
len(rate)
# Out:
# 10

# %%
content = soup.find_all('span',class_='review-text-content')
review_content = []
for i in range(0,len(content)):
    review_content.append(content[i].get_text())

# %%
review_content[:] = [reviews.lstrip('\n') for reviews in review_content]

# %%
review_content[:] = [reviews.rstrip('\n') for reviews in review_content]

# %%
review_content
# Out:
# ["  May be my first negative review about the product & Amazon both. I was much elated to receive the iPhone 11 so fast, next day of dispatch i.e. 28/09/19, but the thing I got started heating up every now and then. Contacted Applecare, just to be consoled that it's quite normal. As it continued, tried to return the product by speaking to Amazon customer support but in vain. Some body called me back to convey that only Apple will decide which one to take back. Why is then Amazon took up the sacred duty of selling such an item which they can't exchange/ have no control ? The product developed new issues like proximity sensor malfunction and last but most importantly loosing mobile network every other minute(even had two software updates). It was handed over to the Apple ASP as the return window closed on 10/10/19 (what use it was for??) and diagnosed as having issues and has further been sent to Apple repair facility at Bengaluru. So I'm here w/out my first iPhone after using it(suffe
# ...

# %%
df3 = pd.DataFrame()

# %%
df3['Customer_name'] = cust_name
df3['Review title'] = review_title
df3['Ratings'] = rate
df3['Review Content'] = review_content

# %%
df3
# Out:
#        Customer_name                                       Review title  \
# 0       Suman Biswas             Keep away from Amazon when it's Apple.
# 1               Neha  Do not buy iphone or expensive product from Am...
# 2        shanu Kumar                     Solid premium phone from Apple
# 3        Sunny Kumar                  First Time iPhone User Review :-)
# 4    Amazon Customer                            Worst Experience Ever.!
# 5           Krusshna                      Don’t buy it from this seller
# 6     Satyapal singh                                          iPhone 11
# 7      Gurmeet singh                                Defective Iphone 11
# 8         Ghar Sayan  Best iPhone ever | Super Night Mode | Super Ca...
# 9  Vinay Kumar Gupta                        Too much heat on normal use
#
#               Ratings                                     Review Content
# 0  1.0 out of 5 stars    May be my first negative review about the pr...
# ...

# %%
df3.to_csv(r'C:\Users\pooja\Downloads\customer_review_iphone.csv',index = True)

# %% [markdown]
# # Oppo F17

# %%
link4 = 'https://www.amazon.in/128GB-Storage-Additional-Exchange-Offers/product-reviews/B086KDJ6NP/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

# %%
page = requests.get(link4)
page
# Out:
# <Response [200]>

# %%
soup = bs(page.content,'html.parser')

# %%
names = soup.find_all('span',class_='a-profile-name')
customer_names =[]
for i in range(0,len(names)):
    customer_names.append(names[i].get_text())

customer_names
# Out:
# ['Shajesh',
#  'Abhishek singh',
#  'Shajesh',
#  'Anup roy',
#  'Utkarsh',
#  'Uday Girish',
#  'Abhishek Soharia',
#  'Abhishek singh',
#  'INTELLIGENCE INDIAN',
#  'mohammed kashif',
#  'Ahmed',
#  'vishnu']

# %%
customer_names.pop(0)
# Out:
# 'Shajesh'

# %%
customer_names.pop(0)
# Out:
# 'Abhishek singh'

# %%
customer_names
# Out:
# ['Shajesh',
#  'Anup roy',
#  'Utkarsh',
#  'Uday Girish',
#  'Abhishek Soharia',
#  'Abhishek singh',
#  'INTELLIGENCE INDIAN',
#  'mohammed kashif',
#  'Ahmed',
#  'vishnu']

# %%
title = soup.find_all('a',class_='review-title')
review_title = []
for i in range(0,len(title)):
    review_title.append(title[i].get_text())

review_title[:] = [titles.lstrip('\n') for titles in review_title]
review_title[:] = [titles.rstrip('\n') for titles in review_title]

review_title
# Out:
# ['Premium class in range!',
#  'Awesome. Loved it',
#  'seems absolutely worth the price, actually more than worth',
#  'Nice Phone for General mobile usage, Not recommended for Mobile Photographers / High graphics Gamers',
#  'Awsm 🔥 phone back leather is very excellent',
#  "Can't feel happy with this oppo F17 hanging and video playing issue",
#  'Very Bad Experience with This Oppo model',
#  'Classy phone for Classy people',
#  'Nice one',
#  'Think twice before purchasing']

# %%
rating = soup.find_all('i',class_='review-rating')
rate = []
for i in range(0,len(rating)):
    rate.append(rating[i].get_text())

# %%
rate
# Out:
# ['4.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '2.0 out of 5 stars']

# %%
len(rate)
# Out:
# 12

# %%
rate.pop(0)
# Out:
# '4.0 out of 5 stars'

# %%
rate.pop(0)
# Out:
# '1.0 out of 5 stars'

# %%
rate
# Out:
# ['4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '2.0 out of 5 stars']

# %%
reviews = soup.find_all('span',class_='review-text-content')
review_content = []
for i in range(0,len(reviews)):
    review_content.append(reviews[i].get_text())

review_content[:] = [content.lstrip('\n') for content in review_content]
review_content[:] = [content.rstrip('\n') for content in review_content]

review_content
# Out:
# ['  This review\'s to all those who were eagerly waiting for the phone to launch and get hands on, but before all it\'s always hard to get the "DEMO" at the earliest so.. "IMAGES" above are to those who can\'t find demos much often/needed color/to avoid contacts at stores during Covid.Pros - Leather back warmth feelCons - Back Camera\'s not upto the mark when compared to the phones in market and of this price range, though it has given a sleek and leather finish with minimized thickness. . It\'s pro fades out its Con so can go for it blindly but only if you think "CAMERA\'S" not your "PRIORITY"Features I thought would be there was 9.1 surround music/Dolby Atmos but it comes with:Real Sound Technology, just have a look into it if you\'re specific2. Super Amoled+ Display.Hassle free(Inside the box):Tempered glass comes on the phone itself so no extra work on fixing, which might sometimes go wrong.2. Silicon back case (if you\'re looking for touch and feel of leather back, better not us
# ...

# %%
df4 = pd.DataFrame()

# %%
df4['Customer Name'] = customer_names
df4['Review Title'] = review_title
df4['Ratings'] = rate
df4['Review Content'] = review_content

# %%
df4
# Out:
#          Customer Name                                       Review Title  \
# 0              Shajesh                            Premium class in range!
# 1             Anup roy                                  Awesome. Loved it
# 2              Utkarsh  seems absolutely worth the price, actually mor...
# 3          Uday Girish  Nice Phone for General mobile usage, Not recom...
# 4     Abhishek Soharia        Awsm 🔥 phone back leather is very excellent
# 5       Abhishek singh  Can't feel happy with this oppo F17 hanging an...
# 6  INTELLIGENCE INDIAN           Very Bad Experience with This Oppo model
# 7      mohammed kashif                     Classy phone for Classy people
# 8                Ahmed                                           Nice one
# 9               vishnu                      Think twice before purchasing
#
#               Ratings                                     Review Content
# 0  4.0 out of 5 stars    This review's to all those who were eagerly ...
# ...

# %%
df4.to_csv(r'C:\Users\pooja\Downloads\customer_review_oppo.csv',index = True)

# %% [markdown]
# # Vivo V19

# %%
link5 = 'https://www.amazon.in/Vivo-Storage-Additional-Exchange-Offers/product-reviews/B08444WMGT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

# %%
page = requests.get(link5)

# %%
soup=bs(page.content,'html.parser')

# %%
names = soup.find_all('span',class_='a-profile-name')
cust_name = []
for i in range(0,len(names)):
    cust_name.append(names[i].get_text())

cust_name
# Out:
# ['Soumyaranjan Nanda',
#  'Arjun',
#  'Arjun',
#  'Soumyaranjan Nanda',
#  'Inamul Hoque',
#  'Hiren Rathod',
#  'Yam k',
#  'MUKESH KUMAR MEENA',
#  'Manoj Nayak',
#  'Madan Lal',
#  'Rupinderdeep singh',
#  'vignesh']

# %%
cust_name.pop(0)
# Out:
# 'Soumyaranjan Nanda'

# %%
cust_name.pop(0)
# Out:
# 'Arjun'

# %%
cust_name
# Out:
# ['Arjun',
#  'Soumyaranjan Nanda',
#  'Inamul Hoque',
#  'Hiren Rathod',
#  'Yam k',
#  'MUKESH KUMAR MEENA',
#  'Manoj Nayak',
#  'Madan Lal',
#  'Rupinderdeep singh',
#  'vignesh']

# %%
title = soup.find_all('a',class_='review-title')
review_title = []
for i in range(0,len(title)):
    review_title.append(title[i].get_text())

review_title[:] = [titles.lstrip('\n') for titles in review_title]
review_title[:] = [titles.rstrip('\n') for titles in review_title]

review_title
# Out:
# ["Bad product don't buy😢",
#  'Outstanding..',
#  'Price high',
#  'See my Detail Review',
#  'Camera is too good',
#  'Mobile price high',
#  'Go For It....If U Want All In One Pack',
#  'Super',
#  'Super phone in good price',
#  'not worth for money']

# %%
rating = soup.find_all('i',class_='review-rating')
rate = []
for i in range(0,len(rating)):
    rate.append(rating[i].get_text())

rate
# Out:
# ['5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars']

# %%
rate.pop(0)
# Out:
# '5.0 out of 5 stars'

# %%
rate.pop(0)
# Out:
# '1.0 out of 5 stars'

# %%
rate
# Out:
# ['1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars']

# %%
reviews = soup.find_all('span',class_='review-text-content')
review_content = []
for i in range(0,len(reviews)):
    review_content.append(reviews[i].get_text())

review_content[:] = [content.lstrip('\n') for content in review_content]
review_content[:] = [content.rstrip('\n') for content in review_content]

review_content
# Out:
# ["  Very bad product don't buy 😢",
#  '  Superb phone 👍👌 light weight and have a premium look , camera quality is outstanding and the phone contains to many animations..which makes the phone more interesting ..must buy it guys..profermance is also good , music is loud',
#  '  Price is too much high',
#  '  After 1 month Use1.Look and Build quality Good2. Camera Quality and feature mind blowing3. Battery 33w fast charger too good..charge 10 to 100% in just  40 to 45 minutes4. Ram management super.Good for multitasking...5. Display E3 Super Amoled,picture quality very nice stream any video in full HD like Amazon prime video, Netflix6. Audio output very clear and Loud7. Network Quality Good8. Lot of New AI feature provide in this phoneOverall This smartphone fulfill my all Technical Needs...Good work',
#  "  Superb one the best  in vivo Mobile's v19 superb 🤳 price is little high.. but phone is awesome.",
#  '  Nice mobile but price so high',
# ...

# %%
df5 = pd.DataFrame()

# %%
df5['Customer Name'] = cust_name
df5['review title'] = review_title
df5['Ratings'] = rate
df5['Review Content'] = review_content

# %%
df5
# Out:
#         Customer Name                            review title  \
# 0               Arjun                  Bad product don't buy😢
# 1  Soumyaranjan Nanda                           Outstanding..
# 2        Inamul Hoque                              Price high
# 3        Hiren Rathod                    See my Detail Review
# 4               Yam k                      Camera is too good
# 5  MUKESH KUMAR MEENA                       Mobile price high
# 6         Manoj Nayak  Go For It....If U Want All In One Pack
# 7           Madan Lal                                   Super
# 8  Rupinderdeep singh               Super phone in good price
# 9             vignesh                     not worth for money
#
#               Ratings                                     Review Content
# 0  1.0 out of 5 stars                       Very bad product don't buy 😢
# 1  5.0 out of 5 stars    Superb phone 👍👌 light weight and have a prem...
# ...

# %%
df5.to_csv(r'C:\Users\pooja\Downloads\customer_review_vivo.csv',index = True)

# %% [markdown]
# # Nokia 6.2

# %%
link6 = 'https://www.amazon.in/Nokia-6-2-Ceramic-Black-Storage/product-reviews/B07YP6CFFK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

# %%
page = requests.get(link6)

# %%
soup = bs(page.content,'html.parser')

# %%
names = soup.find_all('span',class_='a-profile-name')
cust_name =[]
for i in range(0,len(names)):
    cust_name.append(names[i].get_text())

cust_name
# Out:
# ['Darshan',
#  'DHEERAJ GUPTA',
#  'Darshan',
#  'DHEERAJ GUPTA',
#  'Sonu keswani',
#  'Vijay',
#  'Shriram Fowkar',
#  'Amazon Customer',
#  'Rohitash Garhwal',
#  'Mandeep kr Gayan',
#  'Mukesh kumar sahu',
#  'Manivannan']

# %%
cust_name.pop(0)
# Out:
# 'Darshan'

# %%
cust_name.pop(0)
# Out:
# 'DHEERAJ GUPTA'

# %%
cust_name
# Out:
# ['Darshan',
#  'DHEERAJ GUPTA',
#  'Sonu keswani',
#  'Vijay',
#  'Shriram Fowkar',
#  'Amazon Customer',
#  'Rohitash Garhwal',
#  'Mandeep kr Gayan',
#  'Mukesh kumar sahu',
#  'Manivannan']

# %%
title = soup.find_all('a',class_='review-title')
review_title =[]
for i in range(0,len(title)):
    review_title.append(title[i].get_text())

review_title[:] = [titles.lstrip('\n') for titles in review_title]
review_title[:] = [titles.rstrip('\n') for titles in review_title]

review_title
# Out:
# ['Much Better than all Chinese mobiles',
#  'Screen bleeding issue',
#  'Not price sensitive',
#  "Not returnable in any condition plz don't by here.",
#  'Wonderful phone... Thumbs up to HMD👍',
#  'Worst phone and poor camera and battery',
#  'Worst service',
#  'Disappointed',
#  'Awesome thanks to Amazon',
#  'BEST PHONE FOR BUDGET 12k']

# %%
rating = soup.find_all('i',class_='review-rating')
rate =[]
for i in range(0,len(rating)):
    rate.append(rating[i].get_text())

rate
# Out:
# ['5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars']

# %%
rate.pop(0)
# Out:
# '5.0 out of 5 stars'

# %%
rate.pop(0)
# Out:
# '1.0 out of 5 stars'

# %%
rate
# Out:
# ['5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars']

# %%
len(rate)
# Out:
# 10

# %%
reviews = soup.find_all('span',class_='review-text-content')
review_content =[]
for i in range(0,len(reviews)):
    review_content.append(reviews[i].get_text())

review_content[:] = [content.lstrip('\n') for content in review_content]
review_content[:] = [content.rstrip('\n') for content in review_content]

review_content
# Out:
# ["  Ultimate mid range mobile from Nokia. Excellent features, premium camera quality, good exposure. No doubt about it. Go for it. Chinese mobiles make fool us by showing extra features with low price. But that will not be genuine. but our this Nokia phone is best collection. Guys don't think about price. Bcoz Nokia is a Brand. They don't want to make it cheaper, like Xiaomi, Oppo. They need to maintain their brand value.",
#  "  Poor quality control. My phone is having screen bleeding issue and amazon won't replace it. So, buy wisely.",
#  '  Price is tooo high',
#  "  Worst camera performance and Battery drain rapidly so plz don't buy and this product is not returnable.",
# ...

# %%
df6 = pd.DataFrame()

# %%
df6['Customer Name'] = cust_name
df6['Review Title'] = review_title
df6['Ratings'] = rate
df6['Review Content'] = review_content

# %%
df6
# Out:
#        Customer Name                                       Review Title  \
# 0            Darshan               Much Better than all Chinese mobiles
# 1      DHEERAJ GUPTA                              Screen bleeding issue
# 2       Sonu keswani                                Not price sensitive
# 3              Vijay  Not returnable in any condition plz don't by h...
# 4     Shriram Fowkar               Wonderful phone... Thumbs up to HMD👍
# 5    Amazon Customer            Worst phone and poor camera and battery
# 6   Rohitash Garhwal                                      Worst service
# 7   Mandeep kr Gayan                                       Disappointed
# 8  Mukesh kumar sahu                           Awesome thanks to Amazon
# 9         Manivannan                          BEST PHONE FOR BUDGET 12k
#
#               Ratings                                     Review Content
# 0  5.0 out of 5 stars    Ultimate mid range mobile from Nokia. Excell...
# ...

# %%
df6.to_csv(r'C:\Users\pooja\Downloads\customer_review_Nokia.csv',index = True)

# %% [markdown]
# # LG G8X

# %%
link7 = 'https://www.amazon.in/LG-Screen-Aurora-Black-Screens/product-reviews/B082P36B9X/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

# %%
page = requests.get(link7)

# %%
soup = bs(page.content,'html.parser')

# %%
names = soup.find_all('span',class_='a-profile-name')
cust_name = []
for i in range(0,len(names)):
    cust_name.append(names[i].get_text())

cust_name
# Out:
# ['Sakshi',
#  'Prakash',
#  'Sakshi',
#  'Gaurav',
#  'Ajay',
#  'Devansh aggarwal',
#  'Prakash',
#  'Ishaan',
#  'RookieRon',
#  'Piyush SAHA',
#  'mac',
#  'Abhimanyu Singh']

# %%
cust_name.pop(0)
# Out:
# 'Sakshi'

# %%
cust_name.pop(0)
# Out:
# 'Prakash'

# %%
cust_name
# Out:
# ['Sakshi',
#  'Gaurav',
#  'Ajay',
#  'Devansh aggarwal',
#  'Prakash',
#  'Ishaan',
#  'RookieRon',
#  'Piyush SAHA',
#  'mac',
#  'Abhimanyu Singh']

# %%
title = soup.find_all('a',class_='review-title')
review_title =[]
for i in range(0,len(title)):
    review_title.append(title[i].get_text())

review_title[:] = [titles.lstrip('\n') for titles in review_title]
review_title[:] = [titles.rstrip('\n') for titles in review_title]

review_title
# Out:
# ['Loved the experience More than any other phone Better than IPHONE AND ONEPLUS.',
#  "The Most Practical Phone You'll Probably Never Buy.",
#  'Value for Money, LG, The Best.',
#  'Simply amazing',
#  'Lg not give latest android updates',
#  'The underrated champ!',
#  'Please read.',
#  'Super',
#  'Bang on Buck!!!',
#  'With dual screen it is so much fun !']

# %%
rating = soup.find_all('i',class_='review-rating')
rate =[]
for i in range(0,len(rating)):
    rate.append(rating[i].get_text())

rate
# Out:
# ['5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars']

# %%
rate.pop(0)
# Out:
# '5.0 out of 5 stars'

# %%
rate.pop(0)
# Out:
# '1.0 out of 5 stars'

# %%
rate
# Out:
# ['5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars']

# %%
reviews = soup.find_all('span',class_='review-text-content')
review_content =[]
for i in range(0,len(reviews)):
    review_content.append(reviews[i].get_text())

review_content[:] = [content.lstrip('\n') for content in review_content]
review_content[:] = [content.rstrip('\n') for content in review_content]

review_content
# Out:
# ['  Aswome premium experience.CAMERA Both Back and Front cam good(Can use selfie cam as back camera if you fold the phone)CHARGING if dual screen is on it lasts half a day when in continuous use we can turn off the dual screen to save battery but charging is quick dont know about futureSOUND quality is damn good surround sound even with speakers Dolby(Loved it) EarPhones Dosent have much bass which come in the pack.TOUCH is also decent with 128 GB and good ram no lags as of now while playing games.For PUBG Game Console can be customized.MULTITASKING like screen record and all are damn good over all loved it.',
# ...

# %%
df7 = pd.DataFrame()

# %%
df7['Customer Name'] = cust_name
df7['Review Title'] = review_title
df7['Ratings'] = rate
df7['Review Content'] = review_content

# %%
df7
# Out:
#       Customer Name                                       Review Title  \
# 0            Sakshi  Loved the experience More than any other phone...
# 1            Gaurav  The Most Practical Phone You'll Probably Never...
# 2              Ajay                     Value for Money, LG, The Best.
# 3  Devansh aggarwal                                     Simply amazing
# 4           Prakash                 Lg not give latest android updates
# 5            Ishaan                              The underrated champ!
# 6         RookieRon                                       Please read.
# 7       Piyush SAHA                                              Super
# 8               mac                                    Bang on Buck!!!
# 9   Abhimanyu Singh               With dual screen it is so much fun !
#
#               Ratings                                     Review Content
# 0  5.0 out of 5 stars    Aswome premium experience.CAMERA Both Back a...
# ...

# %%
df7.to_csv(r'C:\Users\pooja\Downloads\customer_review_LG.csv',index = True)

# %% [markdown]
# # Honor 20

# %%
link8 = 'https://www.amazon.in/Honor-Sapphire-Blue-128GB-Storage/product-reviews/B07V7ZWFJB/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

# %%
page = requests.get(link8)

# %%
soup = bs(page.content,'html.parser')

# %%
names = soup.find_all('span',class_='a-profile-name')
cust_name = []
for i in range(0,len(names)):
    cust_name.append(names[i].get_text())

cust_name
# Out:
# ['abhinav arya',
#  'Binal Parmar',
#  'abhinav arya',
#  'Shrinidhi Yeri',
#  'Imran',
#  'Xavr',
#  'rahul kumar',
#  'Abhinav',
#  'Atanu Kundu',
#  'Binal Parmar',
#  'RISHI KUMAR',
#  'law kumar pandey']

# %%
cust_name.pop(0)
# Out:
# 'abhinav arya'

# %%
cust_name.pop(0)
# Out:
# 'Binal Parmar'

# %%
cust_name
# Out:
# ['abhinav arya',
#  'Shrinidhi Yeri',
#  'Imran',
#  'Xavr',
#  'rahul kumar',
#  'Abhinav',
#  'Atanu Kundu',
#  'Binal Parmar',
#  'RISHI KUMAR',
#  'law kumar pandey']

# %%
title = soup.find_all('a',class_='review-title')
review_title =[]
for i in range(0,len(title)):
    review_title.append(title[i].get_text())

review_title[:] = [titles.lstrip('\n') for titles in review_title]
review_title[:] = [titles.rstrip('\n') for titles in review_title]

review_title
# Out:
# ['Premium, yet affordable!',
#  'Full review after 10 day with pros n cons',
#  'Worth every penny',
#  'Awesome allrounder',
#  'Super duper honer. 🙏👍',
#  'Real Good but its OS needs serious overhauling!',
#  "I'm honored to have honor (Honor 20)",
#  'Worst network connectivity',
#  'HONEST REVIEW',
#  'All-rounder']

# %%
rating = soup.find_all('i',class_='review-rating')
rate =[]
for i in range(0,len(rating)):
    rate.append(rating[i].get_text())

rate
# Out:
# ['5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars']

# %%
rate.pop(0)
# Out:
# '5.0 out of 5 stars'

# %%
rate.pop(0)
# Out:
# '1.0 out of 5 stars'

# %%
rate
# Out:
# ['5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars']

# %%
reviews = soup.find_all('span',class_='review-text-content')
review_content =[]
for i in range(0,len(reviews)):
    review_content.append(reviews[i].get_text())

review_content[:] = [content.lstrip('\n') for content in review_content]
review_content[:] = [content.rstrip('\n') for content in review_content]

review_content
# Out:
# ["  I bought this phone at a price of 23k. Here are my initial viewpoints for the phone.Pros:1. In a market full of huge phones, this one is welcome change. Phone is compact and easy to use2. Even though display is not amoled, it is still pretty good3. Phone feels very premium with top notch build quality4. Very capable selfie and rear cameras and probably amongst the best under 30k range. Only worthy selfie challenger in this range is Asus 6z which still costs around 7-8k more for similar spec variant5. Kirin 980 is awesome and draws flagship performance like snapdragon 8556. Good battery life. Kirin processors fare better than snapdragon due to efficient power usage. Do not get fooled by mah numbers7. Phone is zippy. Efficient ram management. No lags at all8. Charges pretty quickly as it comes bundled with a super charger9. No ads experienced like in redmi phones10. Dedicated earpiece ensures good call quality. Some of the premium phones have screen sound technology and I don't fin
# ...

# %%
df8 = pd.DataFrame()

# %%
df8['Customer Name'] = cust_name
df8['Review Title'] = review_title
df8['Ratings'] = rate
df8['Review Content'] = review_content

# %%
df8
# Out:
#       Customer Name                                     Review Title  \
# 0      abhinav arya                         Premium, yet affordable!
# 1    Shrinidhi Yeri        Full review after 10 day with pros n cons
# 2             Imran                                Worth every penny
# 3              Xavr                               Awesome allrounder
# 4       rahul kumar                            Super duper honer. 🙏👍
# 5           Abhinav  Real Good but its OS needs serious overhauling!
# 6       Atanu Kundu             I'm honored to have honor (Honor 20)
# 7      Binal Parmar                       Worst network connectivity
# 8       RISHI KUMAR                                    HONEST REVIEW
# 9  law kumar pandey                                      All-rounder
#
#               Ratings                                     Review Content
# 0  5.0 out of 5 stars    I bought this phone at a price of 23k. Here ...
# ...

# %%
df8.to_csv(r'C:\Users\pooja\Downloads\customer_review_Honor.csv',index = True)

# %% [markdown]
# # Redmi 9A

# %%
link9 = 'https://www.amazon.in/Redmi-9A-2GB-32GB-Storage/product-reviews/B086978F2L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

# %%
page = requests.get(link9)

# %%
soup = bs(page.content,'html.parser')

# %%
names = soup.find_all('span',class_='a-profile-name')
cust_name = []
for i in range(0,len(names)):
    cust_name.append(names[i].get_text())

cust_name
# Out:
# ['suresh.s',
#  'Soumya',
#  'suresh.s',
#  'Deepak chandra joshi',
#  'Soumya',
#  'Sagar',
#  'VISAL V',
#  'Amazon Customer',
#  'Sawroop',
#  'Vijay Pednekar',
#  'sumit anwekar',
#  'Sufiyan Ali khan']

# %%
cust_name.pop(0)
# Out:
# 'suresh.s'

# %%
cust_name.pop(0)
# Out:
# 'Soumya'

# %%
cust_name
# Out:
# ['suresh.s',
#  'Deepak chandra joshi',
#  'Soumya',
#  'Sagar',
#  'VISAL V',
#  'Amazon Customer',
#  'Sawroop',
#  'Vijay Pednekar',
#  'sumit anwekar',
#  'Sufiyan Ali khan']

# %%
title = soup.find_all('a',class_='review-title')
review_title =[]
for i in range(0,len(title)):
    review_title.append(title[i].get_text())

review_title[:] = [titles.lstrip('\n') for titles in review_title]
review_title[:] = [titles.rstrip('\n') for titles in review_title]

review_title
# Out:
# ['Worst experience by the executive',
#  'One of the good choice for low budget phone',
#  "Don't buy this phone",
#  'Made in China product',
#  'Made in China....Not made in india...returning the product',
#  'Good but not up to the mark',
#  'Stop🔴🔴🔴',
#  'Excellent phone',
#  'Lovely love you',
#  'Screen resolution is not good & worst camera ever.. rest so so..']

# %%
rating = soup.find_all('i',class_='review-rating')
rate =[]
for i in range(0,len(rating)):
    rate.append(rating[i].get_text())

rate
# Out:
# ['4.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars']

# %%
rate.pop(0)
# Out:
# '4.0 out of 5 stars'

# %%
rate.pop(0)
# Out:
# '1.0 out of 5 stars'

# %%
rate
# Out:
# ['4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars']

# %%
reviews = soup.find_all('span',class_='review-text-content')
review_content =[]
for i in range(0,len(reviews)):
    review_content.append(reviews[i].get_text())

review_content[:] = [content.lstrip('\n') for content in review_content]
review_content[:] = [content.rstrip('\n') for content in review_content]

review_content
# Out:
# ['  Hello. The Redmi 9 A phone I bought is fine. I know Redmi will always be the best. Because I have been a Redmi customer for about 5 1/2 years. My first Redmi phone was the Redmi 2 Prime. But the Redmi 9 A phone I just bought has been opened by the seller. The lamination cover of the box was peeled off. The sealing sticker on both sides of the box was disassembled and then pasted.I did not send this phone back as I do not want to return the Redmi phone and it is difficult to get the phone on flash sale. I would like to sever the Amazon relationship with this. It was a very bad experience for me. good bye Amazon.',
#  "  If you are looking for low budget phone this can be a good choice for you.If you wanna android phone just for day to day work then it's really good.On playing heavy games it will hange obviously. Camera is fine at this range. When you start your new device it take some time but later it will work smoothly.Phone is light weight with a good look",
# ...

# %%
df9 = pd.DataFrame()

# %%
df9['Customer Name'] = cust_name
df9['Review Title'] = review_title
df9['Ratings'] = rate
df9['Review Content'] = review_content

# %%
df9
# Out:
#           Customer Name                                       Review Title  \
# 0              suresh.s                  Worst experience by the executive
# 1  Deepak chandra joshi        One of the good choice for low budget phone
# 2                Soumya                               Don't buy this phone
# 3                 Sagar                              Made in China product
# 4               VISAL V  Made in China....Not made in india...returning...
# 5       Amazon Customer                        Good but not up to the mark
# 6               Sawroop                                            Stop🔴🔴🔴
# 7        Vijay Pednekar                                    Excellent phone
# 8         sumit anwekar                                    Lovely love you
# 9      Sufiyan Ali khan  Screen resolution is not good & worst camera e...
#
#               Ratings                                     Review Content
# ...

# %%
df9.to_csv(r'C:\Users\pooja\Downloads\customer_review_Redmi9A.csv',index = True)

# %% [markdown]
# # OnePlus 6T Mclaren

# %%
link10 = 'https://www.amazon.in/Test-Exclusive-734/product-reviews/B07DJCVTBH/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

# %%
page = requests.get(link10)

# %%
soup = bs(page.content,'html.parser')

# %%
names = soup.find_all('span',class_='a-profile-name')
cust_name = []
for i in range(0,len(names)):
    cust_name.append(names[i].get_text())

cust_name
# Out:
# ['Tanmay Shukla',
#  'Surbhi Garg',
#  'Tanmay Shukla',
#  'Surbhi Garg',
#  'klknow',
#  'abdulkadir garari',
#  'Anshu K.',
#  'nagaraj s.',
#  'Regidi Mahesh Dora',
#  'Vaibhav Narvaria',
#  'Aakash Sinha',
#  'Mumtaz Alam']

# %%
cust_name.pop(0)
# Out:
# 'Tanmay Shukla'

# %%
cust_name.pop(0)
# Out:
# 'Surbhi Garg'

# %%
cust_name
# Out:
# ['Tanmay Shukla',
#  'Surbhi Garg',
#  'klknow',
#  'abdulkadir garari',
#  'Anshu K.',
#  'nagaraj s.',
#  'Regidi Mahesh Dora',
#  'Vaibhav Narvaria',
#  'Aakash Sinha',
#  'Mumtaz Alam']

# %%
title = soup.find_all('a',class_='review-title')
review_title =[]
for i in range(0,len(title)):
    review_title.append(title[i].get_text())

review_title[:] = [titles.lstrip('\n') for titles in review_title]
review_title[:] = [titles.rstrip('\n') for titles in review_title]

review_title
# Out:
# ['Flagship Killer',
#  'Camera quality is very poor.',
#  'Dead on arrival',
#  'Not worth to buy 6T',
#  'Beautiful phone',
#  'Awesome value for the money',
#  'NO WAY GOING TO BE A CUSTOMER OF A COMPANY (Oneplus6T) THAT CANNOT GET NEW CUSTOMER SERVICE CORRECT',
#  'Superb phone',
#  'OnePlust 6T McLaren Edition - Salute to Speed!',
#  'Waste of money']

# %%
rating = soup.find_all('i',class_='review-rating')
rate =[]
for i in range(0,len(rating)):
    rate.append(rating[i].get_text())

rate
# Out:
# ['5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars']

# %%
rate.pop(0)
# Out:
# '5.0 out of 5 stars'

# %%
rate.pop(0)
# Out:
# '2.0 out of 5 stars'

# %%
rate
# Out:
# ['5.0 out of 5 stars',
#  '2.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars']

# %%
reviews = soup.find_all('span',class_='review-text-content')
review_content =[]
for i in range(0,len(reviews)):
    review_content.append(reviews[i].get_text())

review_content[:] = [content.lstrip('\n') for content in review_content]
review_content[:] = [content.rstrip('\n') for content in review_content]

review_content
# Out:
# ["  I got this phone on Friday evening.Pros:Great battery lifeAmazing performancePremium designImpressive rear and front cameraIn display fingerprint scanner is really fastCons:No headphone jack but you'll get a converterNo notification LEDNo microSD card slotI will give points on my personal experience of 2 days full usage as below:Weight: 9/10OS: 10/10Screen size: 10/10CPU: 10/10Performance: 10/10Storage: 10/10 (you'll get approx 113 gb for use)Battery: 8/10Rear camera: 10/10Front camera: 10/10In display fingerprint scanner: 9/10Face unlock: 10/10I hope this will help full.",
#  '  Camera quality is not upto the mark. I visited one plus store and the store representative checked my phone and compared the camera quality with his demo phone. He noticed a significant difference between the two.I request Amazon to replace my phone with a new one as it is evident that this phone has some problems.',
# ...

# %%
df10 = pd.DataFrame()

# %%
df10['Customer Name'] = cust_name
df10['Review Title'] = review_title
df10['Ratings'] = rate
df10['Review Content'] = review_content

# %%
df10.to_csv(r'C:\Users\pooja\Downloads\customer_review_Redmi9A.csv',index = True)

# %%
df10
# Out:
#         Customer Name                                       Review Title  \
# 0       Tanmay Shukla                                    Flagship Killer
# 1         Surbhi Garg                       Camera quality is very poor.
# 2              klknow                                    Dead on arrival
# 3   abdulkadir garari                                Not worth to buy 6T
# 4            Anshu K.                                    Beautiful phone
# 5          nagaraj s.                        Awesome value for the money
# 6  Regidi Mahesh Dora  NO WAY GOING TO BE A CUSTOMER OF A COMPANY (On...
# 7    Vaibhav Narvaria                                       Superb phone
# 8        Aakash Sinha     OnePlust 6T McLaren Edition - Salute to Speed!
# 9         Mumtaz Alam                                     Waste of money
#
#               Ratings                                     Review Content
# 0  5.0 out of 5 stars    I got this phone on Friday evening.Pros:Grea...
# ...

# %% [markdown]
# # Merging all the data frames in one Excel file

# %%
writer = pd.ExcelWriter(r'C:\Users\pooja\scraped_data.xlsx', engine='xlsxwriter')

# %%
df.to_excel(writer,sheet_name='One_Plus_7T')

# %%
df2.to_excel(writer,sheet_name='Samsung_galaxy_M31')

# %%
df3.to_excel(writer,sheet_name='Apple_iphone11')

# %%
df4.to_excel(writer,sheet_name='oppo_F17')

# %%
df5.to_excel(writer,sheet_name='Vivo_V19')

# %%
df6.to_excel(writer,sheet_name='Nokia_6.2')

# %%
df7.to_excel(writer,sheet_name='LG_G8X')

# %%
df8.to_excel(writer,sheet_name='Honor_20')

# %%
df9.to_excel(writer,sheet_name='Redmi_9A')

# %%
df10.to_excel(writer,sheet_name='OnePlus_6T_McLaren')

# %%
writer.save()
