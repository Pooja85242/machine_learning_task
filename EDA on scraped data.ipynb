# %%
import pandas as pd
import io
from gensim.models import Word2Vec
from sklearn.cluster import KMeans
import re
import string

# %%
df1 = pd.read_excel('scraped_data.xlsx',sheet_name='One_Plus_7T', index_col=[0])
df2 = pd.read_excel('scraped_data.xlsx',sheet_name='Samsung_galaxy_M31', index_col=[0])
df3 = pd.read_excel('scraped_data.xlsx',sheet_name='Apple_iphone11', index_col=[0])
df4 = pd.read_excel('scraped_data.xlsx',sheet_name='oppo_F17', index_col=[0])
df5 = pd.read_excel('scraped_data.xlsx',sheet_name='Vivo_V19', index_col=[0])
df6 = pd.read_excel('scraped_data.xlsx',sheet_name='Nokia_6.2', index_col=[0])
df7 = pd.read_excel('scraped_data.xlsx',sheet_name='LG_G8X', index_col=[0])
df8 = pd.read_excel('scraped_data.xlsx',sheet_name='Honor_20', index_col=[0])
df9 = pd.read_excel('scraped_data.xlsx',sheet_name='Redmi_9A', index_col=[0])
df10 = pd.read_excel('scraped_data.xlsx',sheet_name='OnePlus_6T_McLaren', index_col=[0])

# %%
df
# Out:
#                                       Review_Content  \
# 0    After reading a lot of geeky reviews on YouT...
# 1    Detailed review --Design - 4/5+Reduced notch...
# 2    Awesome experience..best in class camera... ...
# 3    I received One Plus 7T 2 days back. I will d...
# 4    My first one+7t & its make me so sad. I rece...
# 5    This phone has great performance, good camer...
# 6    THIS IS ONE OF THE WORST PHONE I HAVE EVER P...
# 7                                   No earphone jack
# 8    A One plus user.Oneplus One -> Oneplus 3T ->...
# 9    The smart Lock feature is not working on the...
#
#                                        clean_content
# 0    after reading a lot of geeky reviews on yout...
# 1    detailed review design   notchpremium glass ...
# 2    awesome experiencebest in class camera oxyge...
# 3    i received one plus   days back i will descr...
# 4    my first   its make me so sad i received the...
# 5    this phone has great performance good camera...
# ...

# %%
# cleaning data review title and content
dfon= df10[["Review_Title"]]
dfon["Review_Title"] = dfon["Review_Title"].astype(str)

def text_clean(text):
    text = text.lower() 
    text = re.sub('\[.*?\]','',text)
    text = re.sub('[%s]'%re.escape(string.punctuation),'',text)
    text = re.sub('\w*\d\w*','',text)
    text =re.sub('[''""_]','',text)
    text = re.sub('\n','',text)
    text =re.sub('[é]','',text)
    return text

cleaned = lambda x :text_clean(x)

dfon["clean_title"]=pd.DataFrame(dfon.Review_Title.apply(cleaned))

dfon= df10[["Review_Content"]]
dfon["Review_Content"] = dfon["Review_Content"].astype(str)

def text_clean(text):
    text = text.lower() 
    text = re.sub('\[.*?\]','',text)
    text = re.sub('[%s]'%re.escape(string.punctuation),'',text)
    text = re.sub('\w*\d\w*','',text)
    text =re.sub('[''""_]','',text)
    text = re.sub('\n','',text)
    text =re.sub('[é]','',text)
    return text

cleaned = lambda x :text_clean(x)

dfon["clean_content"]=pd.DataFrame(dfon.Review_Content.apply(cleaned))

dfon.head()
# Out:
# C:\Users\pooja\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\pooja\anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\pooja\anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfs
# Out:
#                                       Review_Content  \
# 0    Best camera, very good battery life, eat bod...
# 1    This is best thing you can get at this price...
# 2    3rd class front camera. 32 MP front camera n...
# 3    Lets just begin with the obvious. This phone...
# 4    I am using it from 3 days , 6000 mah battery...
# 5    The phone was wrapped in dust. Although it w...
# 6    Software is no working. No sounds in media, ...
# 7    Phone camera is not good , samsung says it's...
# 8    Camera front is worst, not up to the mark. W...
# 9    Not a Samsung performance. It seems it was l...
#
#                                        clean_content
# 0    best camera very good battery life eat body ...
# 1    this is best thing you can get at this price...
# 2     class front camera  mp front camera n looks...
# 3    lets just begin with the obvious this phones...
# 4    i am using it from  days   mah battery is ju...
# 5    the phone was wrapped in dust although it wa...
# ...

# %%
dfa
# Out:
#                                       Review_Content  \
# 0    May be my first negative review about the pr...
# 1    Please do not buy expensive product like iph...
# 2    Awesome Phone. Nice upgrade from iPhone 6s t...
# 3    The iPhone design is good and the camera qua...
# 4    My Phone is Producing Too Much Heat Even Did...
# 5    Bought the mobile from appario retail ltd. M...
# 6    Defective product,got heat up within 5 minut...
# 7    The product i got was defective . The face i...
# 8    In my opinion, don’t  think much about the p...
# 9    Just after i switched it on, it started prod...
#
#                                        clean_content
# 0    may be my first negative review about the pr...
# 1    please do not buy expensive product like iph...
# 2    awesome phone nice upgrade from iphone  to i...
# 3    the iphone design is good and the camera qua...
# 4    my phone is producing too much heat even did...
# 5    bought the mobile from appario retail ltd mo...
# ...

# %%
dfo
# Out:
#                                       Review_Content  \
# 0    This review's to all those who were eagerly ...
# 1    Hi, I am writing this review after 3 days of...
# 2    i like the camera quality, images and videos...
# 3    So it's been three days since I'm using this...
# 4    1st Buyer  of OPPO F17Awssm back leather and...
# 5    Hi I got this phone 24 sept morning .phone i...
# 6    There is no inbuilt call recording&there is ...
# 7    CLASSY PHONE FOR CLASSY PEOPLE, IF U LIVE A ...
# 8    It is nice phone but it is little bit higher...
# 9    It's not worth for this amount after Unboxin...
#
#                                        clean_content
# 0    this reviews to all those who were eagerly w...
# 1    hi i am writing this review after  days of  ...
# 2    i like the camera quality images and videos ...
# 3    so its been three days since im using this p...
# 4     buyer  of oppo  back leather and fantastic ...
# 5    hi i got this phone  sept morning phone is g...
# ...

# %%
dfv
# Out:
#                                       Review_Content  \
# 0                       Very bad product don't buy 😢
# 1    Superb phone 👍👌 light weight and have a prem...
# 2                             Price is too much high
# 3    After 1 month Use1.Look and Build quality Go...
# 4    Superb one the best  in vivo Mobile's v19 su...
# 5                      Nice mobile but price so high
# 6    Expect Price.... Everything Is PerfectA Beau...
# 7                                 Super mobile phone
# 8    Awesome phone at this price.Battery back up ...
# 9    This phone is not worth for 28k, performance...
#
#                                        clean_content
# 0                        very bad product dont buy 😢
# 1    superb phone 👍👌 light weight and have a prem...
# 2                             price is too much high
# 3    after  month  and build quality  camera qual...
# 4    superb one the best  in vivo mobiles  superb...
# 5                      nice mobile but price so high
# ...

# %%
dfn
# Out:
#                                       Review_Content  \
# 0    Ultimate mid range mobile from Nokia. Excell...
# 1    Poor quality control. My phone is having scr...
# 2                                 Price is tooo high
# 3    Worst camera performance and Battery drain r...
# 4    In the sale for exchange you get Rs. 2000/- ...
# 5    Very very bad camera and worst battery don't...
# 6    Worst service and worst product. Now I feel ...
# 7                                      Price is high
# 8                           Awesome thanks to Amazon
# 9    Mid range mobile with awesome display with H...
#
#                                        clean_content
# 0    ultimate mid range mobile from nokia excelle...
# 1    poor quality control my phone is having scre...
# 2                                 price is tooo high
# 3    worst camera performance and battery drain r...
# 4    in the sale for exchange you get rs  extra f...
# 5    very very bad camera and worst battery dont ...
# ...

# %%
dfl
# Out:
#                                       Review_Content  \
# 0    Aswome premium experience.CAMERA Both Back a...
# 1    So, I'll say this outright, I am not a big s...
# 2    My 1st LG Phone, Finalized it the moment I s...
# 3          Amazing for playing games and office work
# 4    I have lg g6 worth rs 40,000.00 but lg give ...
# 5    Pros:1. Excellent build quality with water r...
# 6    After 1 month of use the Hinge is of the  lo...
# 7                   Super phone star of the new year
# 8    LG G8x is true value for money. considering ...
# 9    I was looking to buy a new phone for quite s...
#
#                                        clean_content
# 0    aswome premium experiencecamera both back an...
# 1    so ill say this outright i am not a big suck...
# 2    my  lg phone finalized it the moment i saw t...
# 3          amazing for playing games and office work
# 4    i have lg  worth rs  but lg give only one an...
# 5     excellent build quality with water resistan...
# ...

# %%
dfh
# Out:
#                                       Review_Content  \
# 0    I bought this phone at a price of 23k. Here ...
# 1    Edited on November 9Using the phone since 10...
# 2    Using this mobile for a week now I must say ...
# 3    Pros..... An awesome phone for the price you...
# 4                                 Super duper honer.
# 5    Except the fact that the OS on this phone ne...
# 6    If I have to tell in one word about this pho...
# 7    The mobile has worst network connectivity. I...
# 8    The mobile have super fast perfomance and th...
# 9    It is value for money. I bought honor 20 fou...
#
#                                        clean_content
# 0    i bought this phone at a price of  here are ...
# 1    edited on november  the phone since  daybatt...
# 2    using this mobile for a week now i must say ...
# 3    pros an awesome phone for the price you pay ...
# 4                                  super duper honer
# 5    except the fact that the os on this phone ne...
# ...

# %%
dfr
# Out:
#                                       Review_Content  \
# 0    Hello. The Redmi 9 A phone I bought is fine....
# 1    If you are looking for low budget phone this...
# 2    Both 13 MP and 5MP Camera quality is good. H...
# 3                              Made in China product
# 4    Made in china...The country of origin should...
# 5    Good battery. But phone hangs a.lot. need to...
# 6    Do not go for it...First mobile from Redmi w...
# 7    Nice phone, looks pretty.good backup of batt...
# 8    Lovely low budget mobile love u redmi nice l...
# 9    Worst camera ever...both front & back... & S...
#
#                                        clean_content
# 0    hello the redmi  a phone i bought is fine i ...
# 1    if you are looking for low budget phone this...
# 2    both  mp and  camera quality is good have lo...
# 3                              made in china product
# 4    made in chinathe country of origin should be...
# 5    good battery but phone hangs alot need to re...
# ...

# %%
dfon
# Out:
#                                       Review_Content  \
# 0    I got this phone on Friday evening.Pros:Grea...
# 1    Camera quality is not upto the mark. I visit...
# 2    I charged the phone completely out of the bo...
# 3    One plus 6 was costing 28k during the big bi...
# 4    Good build.amazing battery life. ( Minimum 3...
# 5    Phone is simply superb in all aspects...low ...
# 6    Two days back I received 6T and had many pro...
# 7    After replace the handset issue was resolved...
# 8    This has by far been the best phone I have e...
# 9    Battery-Extremely PoorCamera-SatisfactoryLoo...
#
#                                        clean_content
# 0    i got this phone on friday eveningprosgreat ...
# 1    camera quality is not upto the mark i visite...
# 2    i charged the phone completely out of the bo...
# 3    one plus  was costing  during the big billio...
# 4    good buildamazing battery life  minimum  day...
# 5    phone is simply superb in all aspectslow lig...
# ...

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pooja\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
 from nltk.corpus import stopwords
", ".join(stopwords.words('english'))
# Out:
# "i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, m
# ...

# %% [markdown]
# # Removing StopWords

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

df["text_stop"] = df["clean_content"].apply(lambda text: remove_stopwords(text))
df.head()
# Out:
# C:\Users\pooja\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       Review_Content  \
# 0    After reading a lot of geeky reviews on YouT...
# 1    Detailed review --Design - 4/5+Reduced notch...
# 2    Awesome experience..best in class camera... ...
# 3    I received One Plus 7T 2 days back. I will d...
# 4    My first one+7t & its make me so sad. I rece...
#
#                                        clean_content  \
# 0    after reading a lot of geeky reviews on yout...
# 1    detailed review design   notchpremium glass ...
# 2    awesome experiencebest in class camera oxyge...
# 3    i received one plus   days back i will descr...
# ...

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

dfs["text_stop"] = dfs["clean_content"].apply(lambda text: remove_stopwords(text))
dfs.head()
# Out:
# C:\Users\pooja\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       Review_Content  \
# 0    Best camera, very good battery life, eat bod...
# 1    This is best thing you can get at this price...
# 2    3rd class front camera. 32 MP front camera n...
# 3    Lets just begin with the obvious. This phone...
# 4    I am using it from 3 days , 6000 mah battery...
#
#                                        clean_content  \
# 0    best camera very good battery life eat body ...
# 1    this is best thing you can get at this price...
# 2     class front camera  mp front camera n looks...
# 3    lets just begin with the obvious this phones...
# ...

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

dfa["text_stop"] = dfa["clean_content"].apply(lambda text: remove_stopwords(text))
dfa.head()
# Out:
# C:\Users\pooja\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       Review_Content  \
# 0    May be my first negative review about the pr...
# 1    Please do not buy expensive product like iph...
# 2    Awesome Phone. Nice upgrade from iPhone 6s t...
# 3    The iPhone design is good and the camera qua...
# 4    My Phone is Producing Too Much Heat Even Did...
#
#                                        clean_content  \
# 0    may be my first negative review about the pr...
# 1    please do not buy expensive product like iph...
# 2    awesome phone nice upgrade from iphone  to i...
# 3    the iphone design is good and the camera qua...
# ...

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

dfo["text_stop"] = dfo["clean_content"].apply(lambda text: remove_stopwords(text))
dfo.head()
# Out:
# C:\Users\pooja\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       Review_Content  \
# 0    This review's to all those who were eagerly ...
# 1    Hi, I am writing this review after 3 days of...
# 2    i like the camera quality, images and videos...
# 3    So it's been three days since I'm using this...
# 4    1st Buyer  of OPPO F17Awssm back leather and...
#
#                                        clean_content  \
# 0    this reviews to all those who were eagerly w...
# 1    hi i am writing this review after  days of  ...
# 2    i like the camera quality images and videos ...
# 3    so its been three days since im using this p...
# ...

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

dfv["text_stop"] = dfv["clean_content"].apply(lambda text: remove_stopwords(text))
dfv.head()
# Out:
# C:\Users\pooja\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       Review_Content  \
# 0                       Very bad product don't buy 😢
# 1    Superb phone 👍👌 light weight and have a prem...
# 2                             Price is too much high
# 3    After 1 month Use1.Look and Build quality Go...
# 4    Superb one the best  in vivo Mobile's v19 su...
#
#                                        clean_content  \
# 0                        very bad product dont buy 😢
# 1    superb phone 👍👌 light weight and have a prem...
# 2                             price is too much high
# 3    after  month  and build quality  camera qual...
# ...

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

dfn["text_stop"] = dfn["clean_content"].apply(lambda text: remove_stopwords(text))
dfn.head()
# Out:
# C:\Users\pooja\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       Review_Content  \
# 0    Ultimate mid range mobile from Nokia. Excell...
# 1    Poor quality control. My phone is having scr...
# 2                                 Price is tooo high
# 3    Worst camera performance and Battery drain r...
# 4    In the sale for exchange you get Rs. 2000/- ...
#
#                                        clean_content  \
# 0    ultimate mid range mobile from nokia excelle...
# 1    poor quality control my phone is having scre...
# 2                                 price is tooo high
# 3    worst camera performance and battery drain r...
# ...

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

dfl["text_stop"] = dfl["clean_content"].apply(lambda text: remove_stopwords(text))
dfl.head()
# Out:
# C:\Users\pooja\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       Review_Content  \
# 0    Aswome premium experience.CAMERA Both Back a...
# 1    So, I'll say this outright, I am not a big s...
# 2    My 1st LG Phone, Finalized it the moment I s...
# 3          Amazing for playing games and office work
# 4    I have lg g6 worth rs 40,000.00 but lg give ...
#
#                                        clean_content  \
# 0    aswome premium experiencecamera both back an...
# 1    so ill say this outright i am not a big suck...
# 2    my  lg phone finalized it the moment i saw t...
# 3          amazing for playing games and office work
# ...

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

dfh["text_stop"] = dfh["clean_content"].apply(lambda text: remove_stopwords(text))
dfh.head()
# Out:
# C:\Users\pooja\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       Review_Content  \
# 0    I bought this phone at a price of 23k. Here ...
# 1    Edited on November 9Using the phone since 10...
# 2    Using this mobile for a week now I must say ...
# 3    Pros..... An awesome phone for the price you...
# 4                                 Super duper honer.
#
#                                        clean_content  \
# 0    i bought this phone at a price of  here are ...
# 1    edited on november  the phone since  daybatt...
# 2    using this mobile for a week now i must say ...
# 3    pros an awesome phone for the price you pay ...
# ...

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

dfr["text_stop"] = dfr["clean_content"].apply(lambda text: remove_stopwords(text))
dfr.head()
# Out:
# C:\Users\pooja\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       Review_Content  \
# 0    Hello. The Redmi 9 A phone I bought is fine....
# 1    If you are looking for low budget phone this...
# 2    Both 13 MP and 5MP Camera quality is good. H...
# 3                              Made in China product
# 4    Made in china...The country of origin should...
#
#                                        clean_content  \
# 0    hello the redmi  a phone i bought is fine i ...
# 1    if you are looking for low budget phone this...
# 2    both  mp and  camera quality is good have lo...
# 3                              made in china product
# ...

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

dfon["text_stop"] = dfon["clean_content"].apply(lambda text: remove_stopwords(text))
dfon.head()
# Out:
# C:\Users\pooja\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                       Review_Content  \
# 0    I got this phone on Friday evening.Pros:Grea...
# 1    Camera quality is not upto the mark. I visit...
# 2    I charged the phone completely out of the bo...
# 3    One plus 6 was costing 28k during the big bi...
# 4    Good build.amazing battery life. ( Minimum 3...
#
#                                        clean_content  \
# 0    i got this phone on friday eveningprosgreat ...
# 1    camera quality is not upto the mark i visite...
# 2    i charged the phone completely out of the bo...
# 3    one plus  was costing  during the big billio...
# ...

# %% [markdown]
# # Lemmatization

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\pooja\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])
# one plus 7t
df["text_lemmatized"] = df["Review_Content"].apply(lambda text: lemmatize_words(text))
df.head()
# Out:
#                                       Review_Content  \
# 0    After reading a lot of geeky reviews on YouT...
# 1    Detailed review --Design - 4/5+Reduced notch...
# 2    Awesome experience..best in class camera... ...
# 3    I received One Plus 7T 2 days back. I will d...
# 4    My first one+7t & its make me so sad. I rece...
#
#                                        clean_content  \
# 0    after reading a lot of geeky reviews on yout...
# 1    detailed review design   notchpremium glass ...
# 2    awesome experiencebest in class camera oxyge...
# 3    i received one plus   days back i will descr...
# 4    my first   its make me so sad i received the...
#
#                                            text_stop  \
# 0  reading lot geeky reviews youtube portals boug...
# 1  detailed review design notchpremium glass back...
# 2  awesome experiencebest class camera oxygen oslove
# 3  received one plus days back describe experienc...
# ...

# %%
# samsung mobile

dfs["text_lemmatized"] = dfs["Review_Content"].apply(lambda text: lemmatize_words(text))
dfs.head()
# Out:
#                                       Review_Content  \
# 0    Best camera, very good battery life, eat bod...
# 1    This is best thing you can get at this price...
# 2    3rd class front camera. 32 MP front camera n...
# 3    Lets just begin with the obvious. This phone...
# 4    I am using it from 3 days , 6000 mah battery...
#
#                                        clean_content  \
# 0    best camera very good battery life eat body ...
# 1    this is best thing you can get at this price...
# 2     class front camera  mp front camera n looks...
# 3    lets just begin with the obvious this phones...
# 4    i am using it from  days   mah battery is ju...
#
#                                            text_stop  \
# 0  best camera good battery life eat body materia...
# 1  best thing get price reputed brand made india ...
# 2  class front camera mp front camera n looks lik...
# 3  lets begin obvious phones quality doesnt meet ...
# ...

# %%
# apple iphone 11
dfa["text_lemmatized"] = dfa["Review_Content"].apply(lambda text: lemmatize_words(text))
dfa.head()
# Out:
#                                       Review_Content  \
# 0    May be my first negative review about the pr...
# 1    Please do not buy expensive product like iph...
# 2    Awesome Phone. Nice upgrade from iPhone 6s t...
# 3    The iPhone design is good and the camera qua...
# 4    My Phone is Producing Too Much Heat Even Did...
#
#                                        clean_content  \
# 0    may be my first negative review about the pr...
# 1    please do not buy expensive product like iph...
# 2    awesome phone nice upgrade from iphone  to i...
# 3    the iphone design is good and the camera qua...
# 4    my phone is producing too much heat even did...
#
#                                            text_stop  \
# 0  may first negative review product amazon much ...
# 1  please buy expensive product like iphone amazo...
# 2  awesome phone nice upgrade iphone iphone love ...
# 3  iphone design good camera quality awesome also...
# ...

# %%
#oppo f17
dfo["text_lemmatized"] = dfo["Review_Content"].apply(lambda text: lemmatize_words(text))
dfo.head()
# Out:
#                                       Review_Content  \
# 0    This review's to all those who were eagerly ...
# 1    Hi, I am writing this review after 3 days of...
# 2    i like the camera quality, images and videos...
# 3    So it's been three days since I'm using this...
# 4    1st Buyer  of OPPO F17Awssm back leather and...
#
#                                        clean_content  \
# 0    this reviews to all those who were eagerly w...
# 1    hi i am writing this review after  days of  ...
# 2    i like the camera quality images and videos ...
# 3    so its been three days since im using this p...
# 4     buyer  of oppo  back leather and fantastic ...
#
#                                            text_stop  \
# 0  reviews eagerly waiting phone launch get hands...
# 1  hi writing review days firstly thanks amazon g...
# 2  like camera quality images videos sharp clear ...
# 3  three days since im using phone im completely ...
# ...

# %%
# vivo v19
dfv["text_lemmatized"] = dfv["Review_Content"].apply(lambda text: lemmatize_words(text))
dfv.head()
# Out:
#                                       Review_Content  \
# 0                       Very bad product don't buy 😢
# 1    Superb phone 👍👌 light weight and have a prem...
# 2                             Price is too much high
# 3    After 1 month Use1.Look and Build quality Go...
# 4    Superb one the best  in vivo Mobile's v19 su...
#
#                                        clean_content  \
# 0                        very bad product dont buy 😢
# 1    superb phone 👍👌 light weight and have a prem...
# 2                             price is too much high
# 3    after  month  and build quality  camera qual...
# 4    superb one the best  in vivo mobiles  superb...
#
#                                            text_stop  \
# 0                             bad product dont buy 😢
# 1  superb phone 👍👌 light weight premium look came...
# 2                                    price much high
# 3  month build quality camera quality feature min...
# ...

# %%
#nokia 6.2
dfn["text_lemmatized"] = dfn["Review_Content"].apply(lambda text: lemmatize_words(text))
dfn.head()
# Out:
#                                       Review_Content  \
# 0    Ultimate mid range mobile from Nokia. Excell...
# 1    Poor quality control. My phone is having scr...
# 2                                 Price is tooo high
# 3    Worst camera performance and Battery drain r...
# 4    In the sale for exchange you get Rs. 2000/- ...
#
#                                        clean_content  \
# 0    ultimate mid range mobile from nokia excelle...
# 1    poor quality control my phone is having scre...
# 2                                 price is tooo high
# 3    worst camera performance and battery drain r...
# 4    in the sale for exchange you get rs  extra f...
#
#                                            text_stop  \
# 0  ultimate mid range mobile nokia excellent feat...
# 1  poor quality control phone screen bleeding iss...
# 2                                    price tooo high
# 3  worst camera performance battery drain rapidly...
# ...

# %%
#LG
dfl["text_lemmatized"] = dfl["Review_Content"].apply(lambda text: lemmatize_words(text))
dfl.head()
# Out:
#                                       Review_Content  \
# 0    Aswome premium experience.CAMERA Both Back a...
# 1    So, I'll say this outright, I am not a big s...
# 2    My 1st LG Phone, Finalized it the moment I s...
# 3          Amazing for playing games and office work
# 4    I have lg g6 worth rs 40,000.00 but lg give ...
#
#                                        clean_content  \
# 0    aswome premium experiencecamera both back an...
# 1    so ill say this outright i am not a big suck...
# 2    my  lg phone finalized it the moment i saw t...
# 3          amazing for playing games and office work
# 4    i have lg  worth rs  but lg give only one an...
#
#                                            text_stop  \
# 0  aswome premium experiencecamera back front cam...
# 1  ill say outright big sucker mobile phones high...
# 2  lg phone finalized moment saw phone design sim...
# 3                  amazing playing games office work
# ...

# %%
#honor 20
dfh["text_lemmatized"] = dfh["Review_Content"].apply(lambda text: lemmatize_words(text))
dfh.head()
# Out:
#                                       Review_Content  \
# 0    I bought this phone at a price of 23k. Here ...
# 1    Edited on November 9Using the phone since 10...
# 2    Using this mobile for a week now I must say ...
# 3    Pros..... An awesome phone for the price you...
# 4                                 Super duper honer.
#
#                                        clean_content  \
# 0    i bought this phone at a price of  here are ...
# 1    edited on november  the phone since  daybatt...
# 2    using this mobile for a week now i must say ...
# 3    pros an awesome phone for the price you pay ...
# 4                                  super duper honer
#
#                                            text_stop  \
# 0  bought phone price initial viewpoints market f...
# 1  edited november phone since daybattery really ...
# 2  using mobile week must say power packed phone ...
# 3  pros awesome phone price pay rounder great cli...
# ...

# %%
#redmi 9A
dfr["text_lemmatized"] = dfr["Review_Content"].apply(lambda text: lemmatize_words(text))
dfr.head()
# Out:
#                                       Review_Content  \
# 0    Hello. The Redmi 9 A phone I bought is fine....
# 1    If you are looking for low budget phone this...
# 2    Both 13 MP and 5MP Camera quality is good. H...
# 3                              Made in China product
# 4    Made in china...The country of origin should...
#
#                                        clean_content  \
# 0    hello the redmi  a phone i bought is fine i ...
# 1    if you are looking for low budget phone this...
# 2    both  mp and  camera quality is good have lo...
# 3                              made in china product
# 4    made in chinathe country of origin should be...
#
#                                            text_stop  \
# 0  hello redmi phone bought fine know redmi alway...
# 1  looking low budget phone good choice youif wan...
# 2  mp camera quality good lot pre installed apps ...
# 3                                 made china product
# ...

# %%
#one plus 6T Mclaren
dfon["text_lemmatized"] = dfon["Review_Content"].apply(lambda text: lemmatize_words(text))
dfon.head()
# Out:
#                                       Review_Content  \
# 0    I got this phone on Friday evening.Pros:Grea...
# 1    Camera quality is not upto the mark. I visit...
# 2    I charged the phone completely out of the bo...
# 3    One plus 6 was costing 28k during the big bi...
# 4    Good build.amazing battery life. ( Minimum 3...
#
#                                        clean_content  \
# 0    i got this phone on friday eveningprosgreat ...
# 1    camera quality is not upto the mark i visite...
# 2    i charged the phone completely out of the bo...
# 3    one plus  was costing  during the big billio...
# 4    good buildamazing battery life  minimum  day...
#
#                                            text_stop  \
# 0  got phone friday eveningprosgreat battery life...
# 1  camera quality upto mark visited one plus stor...
# 2  charged phone completely box turned went onepl...
# 3  one plus costing big billion sale costs worth ...
# ...
